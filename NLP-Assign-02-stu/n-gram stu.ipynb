# %% [markdown]
# ### 导入库

# %%
import re
from collections import defaultdict

# %% [markdown]
# ### 读取文本文件
#
# 划分测试集和训练集

# %%
#读取盖茨比文本(gaicibi.txt)
text = open('gaicibi.txt', 'r', encoding='utf-8').read()

#将完整文本划分为训练集和测试集，80%作为训练集，20%作为测试集
train_size = int(len(text) * 0.8)
train_text = text[:train_size]
test_text = text[train_size:]

# %% [markdown]
# ### 文本预处理
#
# 对输入的文本进行预处理，包括替换换行符、删除多余空白符、基于标点符号分割句子。你不需要为每一个句子添加起始和终止符号。返回一个句子列表。
#
# 经过文本预处理的句子列表示例：["了不起的盖茨比", "作者弗司各特菲茨杰拉德", "美国中西部城市卡罗威世家的后裔尼克厌倦了中西部的生活"...]
#
# 输出示例：
# ```
# Sentence 1: 了不起的盖茨比
# Sentence 2: 作者弗司各特菲茨杰拉德
# Sentence 3: 美国中西部城市卡罗威世家的后裔尼克厌倦了中西部的生活
# Sentence 4: 到纽约当证券交易人并在市郊长岛西卵区租了一套小屋
# Sentence 5: 他的邻居便是豪华的盖茨比公馆
# Sentence 6: 小海湾对面的东卵区宫殿式的大厦住着从芝加哥搬来的汤姆和黛茜夫妇
# Sentence 7: 黛茜是尼克的远房表妹
# Sentence 8: 汤姆是他大学里的同学
# Sentence 9: 家里很有钱
# Sentence 10: 他性情暴戾盛气凌人
# ...
# ```

# %%
def preprocess_text(text):
    #替换换行符为空格
    text = text.replace('\n', ' ')
    #删除多余空白符
    text = re.sub(r'\s+', ' ', text)
    #删除标点符号，只保留逗号和句号
    text = re.sub(r'[^\w\s，。？！]', '', text)
    #基于逗号、句号、空格进行分句
    sentences = re.split(r'[，。？！ ]', text)
    #去除空句子
    sentences = [s for s in sentences if s]
    return sentences

corpus = preprocess_text(text)

# %% [markdown]
# ### unigram
#
# 实现unigram算法，返回每个词的概率分布
#
# 输出示例：
# ```
# {'了': 0.017678317144610257,
#  '不': 0.012850643111013348,
#  '起': 0.0032647579795547425,
#  '的': 0.043576415017886706,
#  '盖': 0.004086736052421362,
#  '茨': 0.003889924401171608,
#  '比': 0.004434050731097399,
#  '作': 0.0009377496324252984,
#  '者': 0.0007062065133079408,
#  '弗': 0.00015050302742628246,
#  '司': 0.00037046899058777223,
#  '各': 0.0003820461465436401,
#  '特': 0.0012156013753661275,
#  '菲': 0.00021996596316148974,
#  '杰': 0.00041677761441124374,
#  '拉': 0.0007062065133079408,
#  '德': 0.0006946293573520728,
#  '美': 0.0010419440360281093,
#  '国': 0.0010650983479398451,
#  '中': 0.003021637704481517,
#  '西': 0.003889924401171608,
#  '部': 0.0009030181645576947,
#  '城': 0.000683052201396205,
#  '市': 0.0002431202750732255,
#  '卡': 0.00027785174294082916,
# ...
#  '贷': 1.1577155955867882e-05,
#  '资': 4.630862382347153e-05,
#  '籍': 1.1577155955867882e-05,
#  '烫': 4.630862382347153e-05,
#  ...}
# ```

# %%
def calculate_unigram_probabilities(corpus):
    #计算单字的概率
    unigram_counts = defaultdict(int)
    total_unigrams = 0
#  '悉': 9.20439509865961e-05,
#  '随': 0.0006097911752861991,
#  '夏': 0.0002646263590864638,
#  '临': 0.00011505493873324512,
#  '汲': 1.1505493873324512e-05,
#  '取': 0.00011505493873324512,
#  ...}

# %% [markdown]
# ### bigram
#
# 实现bigram算法，返回每个词的概率分
#
# 输出示例：
# ```
# {'了不': 0.015194681861348529,
#  '不起': 0.026268115942028984,
#  '起的': 0.06666666666666667,
#  '的盖': 0.004352872896111433,
#  '盖茨': 0.9261363636363636,
#  '茨比': 0.9702380952380952,
#  '作者': 0.11428571428571428,
#  '者弗': 0.018518518518518517,
#  '弗司': 0.08333333333333333,
#  '司各': 0.17857142857142858,
#  '各特': 0.12121212121212122,
#  '特菲': 0.029411764705882353,
#  '菲茨': 0.47368421052631576,
#  '茨杰': 0.026785714285714284,
#  '杰拉': 0.2571428571428571,
#  '拉德': 0.1694915254237288,
#  '美国': 0.524390243902439,
#  '国中': 0.02197802197802198,
#  '中西': 0.04329004329004329,
#  '西部': 0.07017543859649122,
#  '部城': 0.02631578947368421,
#  '城市': 0.23529411764705882,
#  '市卡': 0.05263157894736842,
#  '卡罗': 0.6521739130434783,
#  '罗威': 0.28888888888888886,
# ...
#  '充当': 0.041666666666666664,
#  '当了': 0.0136986301369863,
#  '了盖': 0.011396011396011397,
#  '比和': 0.019943019943019943,
#  ...}
# ```

# %%
def calculate_bigram_probabilities(corpus):
    """
    计算bigram概率分布
    P(w_i | w_{i-1}) = count(w_{i-1}, w_i) / count(w_{i-1})
    """
    # 统计bigram出现次数
    bigram_counts = defaultdict(int)
    # 统计每个词作为第一个词的出现次数
    unigram_counts = defaultdict(int)
    
    for sentence in corpus:
        # 将句子转换为字符列表
        chars = list(sentence)
        for i in range(len(chars) - 1):
            # 当前词和下一个词组成bigram
            current_char = chars[i]
            next_char = chars[i + 1]
            bigram = (current_char, next_char)
            
            bigram_counts[bigram] += 1
            unigram_counts[current_char] += 1
    
    # 计算bigram条件概率
    bigram_probabilities = {}
    for (current_char, next_char), count in bigram_counts.items():
        probability = count / unigram_counts[current_char]
        bigram_probabilities[current_char + next_char] = probability
    
    return bigram_probabilities

calculate_bigram_probabilities(corpus)
# Out:
# {'了不': 0.015194681861348529,
#  '不起': 0.026268115942028984,
#  '起的': 0.06666666666666667,
#  '的盖': 0.004351610095735422,
#  '盖茨': 0.9261363636363636,
#  '茨比': 0.9702380952380952,
#  '作者': 0.11428571428571428,
#  '者弗': 0.018518518518518517,
#  '弗司': 0.08333333333333333,
#  '司各': 0.17857142857142858,
#  '各特': 0.12121212121212122,
#  '特菲': 0.02912621359223301,
#  '菲茨': 0.47368421052631576,
#  '茨杰': 0.026785714285714284,
#  '杰拉': 0.2571428571428571,
#  '拉德': 0.1694915254237288,
#  '美国': 0.524390243902439,
#  '国中': 0.02197802197802198,
#  '中西': 0.04329004329004329,
#  '西部': 0.07017543859649122,
#  '部城': 0.02631578947368421,
#  '城市': 0.2222222222222222,
#  '市卡': 0.05263157894736842,
#  '忘了': 0.4074074074074074,
#  '但尼': 0.005847953216374269,
#  '克觉': 0.008,
#  '觉得': 0.6455696202531646,
#  '得黛': 0.005780346820809248,
#  '茜远': 0.02857142857142857,
#  '远不': 0.11475409836065574,
#  '不如': 0.005434782608695652,
#  '如盖': 0.011111111111111112,
#  '的梦': 0.0037713954163040323,
#  '梦想': 0.14285714285714285,
#  '的幻': 0.0020307513780098638,
#  '幻梦': 0.2857142857142857,
#  '梦超': 0.047619047619047616,
#  '超越': 0.5454545454545454,
#  '越了': 0.13953488372093023,
#  '了她': 0.032288698955365625,
#  '但黛': 0.011695906432748537,
#  '茜激': 0.02857142857142857,
#  '动的': 0.09433962264150944,
#  '的声': 0.019147084421235857,
#  '声音': 0.4213197969543147,
#  '音把': 0.023809523809523808,
#  '把他': 0.13220338983050847,
#  '他迷': 0.001221001221001221,
#  '迷住': 0.05555555555555555,
#  '住了': 0.1595744680851064,
#  '不久': 0.008152173913043478,
#  '姆带': 0.008547008547008548,
#  '带黛': 0.016666666666666666,
#  '茜到': 0.02857142857142857,
#  '到盖': 0.028315946348733235,
#  '比家': 0.02849002849002849,
#  '家赴': 0.004366812227074236,
#  '赴宴': 0.3333333333333333,
#  '比把': 0.005698005698005698,
#  '的来': 0.002901073397156948,
#  '来宾': 0.001763668430335097,
#  '宾纽': 0.2,
#  '约的': 0.07462686567164178,
#  '的女': 0.006382361473745286,
#  '女大': 0.02040816326530612,
#  '大明': 0.006507592190889371,
#  '明星': 0.045871559633027525,
#  '星和': 0.021739130434782608,
#  '和名': 0.0033222591362126247,
#  '名导': 0.010752688172043012,
#  '导演': 0.75,
#  '演介': 0.05,
#  '介绍': 0.8,
#  '绍给': 0.2,
#  '给他': 0.1415929203539823,
#  '比与': 0.005698005698005698,
#  '茜跳': 0.02857142857142857,
#  '跳舞': 0.16129032258064516,
#  '舞跳': 0.034482758620689655,
#  '跳得': 0.0967741935483871,
#  '得挺': 0.005780346820809248,
#  '挺起': 0.2,
#  '起劲': 0.00392156862745098,
#  '但他': 0.07017543859649122,
#  '他感': 0.0030525030525030525,
#  '感到': 0.5691056910569106,
#  '到很': 0.014903129657228018,
#  '很难': 0.024630541871921183,
#  '难使': 0.037037037037037035,
#  '使她': 0.0761904761904762,
#  '她理': 0.0025380710659898475,
#  '理解': 0.25,
#  '想叫': 0.010101010101010102,
#  '叫黛': 0.0196078431372549,
#  '茜对': 0.02857142857142857,
#  '对汤': 0.02185792349726776,
#  '姆说': 0.05555555555555555,
#  '她从': 0.012690355329949238,
#  '从来': 0.15867158671586715,
#  '来没': 0.059964726631393295,
#  '没爱': 0.027210884353741496,
#  '爱过': 0.2073170731707317,
#  '过他': 0.05476190476190476,
#  '然后': 0.2818991097922849,
#  '后两': 0.006329113924050633,
#  '人自': 0.0030721966205837174,
#  '自由': 0.024691358024691357,
#  '由地': 0.022222222222222223,
#  '地回': 0.01300578034682081,
#  '回老': 0.005649717514124294,
#  '老家': 0.017543859649122806,
#  '早就': 0.13725490196078433,
#  '就出': 0.0071090047393364926,
#  '出门': 0.014492753623188406,
#  '门去': 0.017391304347826087,
#  '去欧': 0.003472222222222222,
#  '洲旅': 0.14285714285714285,
#  '旅行': 0.4,
#  '行了': 0.07692307692307693,
#  '茜既': 0.02857142857142857,
#  '既没': 0.19047619047619047,
#  '没打': 0.017006802721088437,
#  '打来': 0.006097560975609756,
#  '来电': 0.005291005291005291,
#  '电报': 0.06422018348623854,
#  '也没': 0.1095890410958904,
#  '没送': 0.006802721088435374,
#  '送花': 0.058823529411764705,
#  '花圈': 0.04597701149425287,
#  '往日': 0.02631578947368421,
#  '日一': 0.03125,
#  '起花': 0.00392156862745098,
#  '花天': 0.022988505747126436,
#  '天酒': 0.00881057268722467,
#  '酒地': 0.03333333333333333,
#  '地的': 0.015895953757225433,
#  '的朋': 0.004641717435451117,
#  '友没': 0.034482758620689655,
#  '没有': 0.46258503401360546,
#  '有一': 0.1970509383378016,
#  '一个': 0.16305329719963865,
#  '个来': 0.0012077294685990338,
#  '来参': 0.008818342151675485,
#  '加盖': 0.024390243902439025,
#  '的葬': 0.0005802146794313896,
#  '葬礼': 0.6,
#  '唯有': 0.25,
#  '有他': 0.005361930294906166,
#  '年老': 0.012269938650306749,
#  '老的': 0.03508771929824561,
#  '的父': 0.0017406440382941688,
#  '父亲': 0.47368421052631576,
#  '亲和': 0.027777777777777776,
#  '和尼': 0.0033222591362126247,
#  '比为': 0.005698005698005698,
#  '为了': 0.05592105263157895,
#  '了久': 0.000949667616334283,
#  '久久': 0.02857142857142857,
#  '久地': 0.02857142857142857,
#  '地抱': 0.001445086705202312,
#  '抱着': 0.3125,
#  '着的': 0.027896995708154508,
#  '的一': 0.031331592689295036,
#  '个梦': 0.0036231884057971015,
#  '梦而': 0.023809523809523808,
#  '而付': 0.0111731843575419,
#  '付出': 0.375,
#  '出了': 0.08985507246376812,
#  '了很': 0.010446343779677113,
#  '很高': 0.06403940886699508,
#  '高的': 0.1111111111111111,
#  '的代': 0.001450536698578474,
#  '代价': 0.05555555555555555,
#  '他死': 0.0018315018315018315,
#  '死后': 0.06666666666666667,
#  '克发': 0.008,
#  '觉是': 0.012658227848101266,
#  '是汤': 0.007154213036565978,
#  '姆暗': 0.004273504273504274,
#  '暗中': 0.05263157894736842,
#  '中挑': 0.008658008658008658,
#  '挑拨': 0.14285714285714285,
#  '拨威': 0.3333333333333333,
#  '逊去': 0.012658227848101266,
#  '去杀': 0.006944444444444444,
#  '杀死': 0.17647058823529413,
#  '死盖': 0.044444444444444446,
#  '到东': 0.013412816691505217,
#  '东部': 0.2235294117647059,
#  '部鬼': 0.013157894736842105,
#  '鬼影': 0.3,
#  '影幢': 0.03125,
#  '幢幢': 0.5,
#  '世态': 0.014925373134328358,
#  '态炎': 0.09090909090909091,
#  '炎凉': 0.25,
#  '便决': 0.04,
#  '决定': 0.3333333333333333,
#  '定回': 0.019801980198019802,
#  '回中': 0.005649717514124294,
#  '部老': 0.013157894736842105,
#  '作品': 0.1,
#  '品赏': 0.05555555555555555,
#  '赏析': 0.06666666666666667,
#  '小说': 0.06474820143884892,
#  '说通': 0.0035714285714285713,
#  '通过': 0.13636363636363635,
#  '过完': 0.002380952380952381,
#  '完美': 0.024390243902439025,
#  '美的': 0.04878048780487805,
#  '的艺': 0.0005802146794313896,
#  '艺术': 0.8,
#  '术形': 0.2,
#  '形式': 0.14285714285714285,
#  '式描': 0.037037037037037035,
#  '描写': 0.25,
#  '写了': 0.2,
#  '了2': 0.000949667616334283,
#  '20': 0.6666666666666666,
#  '0年': 0.17647058823529413,
#  '年代': 0.024539877300613498,
#  '代贩': 0.027777777777777776,
#  '贩酒': 0.2,
#  '酒暴': 0.016666666666666666,
#  '暴发': 0.2,
#  '发户': 0.01098901098901099,
#  '户盖': 0.05555555555555555,
#  '比所': 0.008547008547008548,
#  '所追': 0.018691588785046728,
#  '追求': 0.5238095238095238,
#  '求的': 0.12121212121212122,
#  '的美': 0.004351610095735422,
#  '国梦': 0.07692307692307693,
#  '梦的': 0.16666666666666666,
#  '幻灭': 0.09523809523809523,
#  '揭示': 1.0,
#  '示了': 0.027777777777777776,
#  '了美': 0.001899335232668566,
#  '国社': 0.01098901098901099,
#  '社会': 0.6666666666666666,
#  '会的': 0.04602510460251046,
#  '的悲': 0.0026109660574412533,
#  '悲剧': 0.26666666666666666,
#  '恋爱': 0.14285714285714285,
#  '爱和': 0.012195121951219513,
#  '和分': 0.0033222591362126247,
#  '分手': 0.04938271604938271,
#  '手本': 0.006993006993006993,
#  '本来': 0.15555555555555556,
#  '来是': 0.015873015873015872,
#  '个很': 0.006038647342995169,
#  '很普': 0.0049261083743842365,
#  '普通': 0.09090909090909091,
#  '通的': 0.022727272727272728,
#  '情故': 0.007042253521126761,
#  '故事': 0.5,
#  '但作': 0.005847953216374269,
#  '者出': 0.037037037037037035,
#  '出手': 0.017391304347826087,
#  '手不': 0.006993006993006993,
#  '不凡': 0.0009057971014492754,
#  '把盖': 0.013559322033898305,
#  '比热': 0.002849002849002849,
#  '恋的': 0.14285714285714285,
#  '的姑': 0.004351610095735422,
#  '姑娘': 0.8947368421052632,
#  '娘当': 0.029411764705882353,
#  '当作': 0.0136986301369863,
#  '作青': 0.014285714285714285,
#  '青春': 0.15789473684210525,
#  '春金': 0.08333333333333333,
#  '钱和': 0.029411764705882353,
#  '和地': 0.0033222591362126247,
#  '地位': 0.008670520231213872,
#  '位的': 0.04225352112676056,
#  '的象': 0.0008703220191470844,
#  '象征': 0.3157894736842105,
#  '作靠': 0.014285714285714285,
#  '靠手': 0.047619047619047616,
#  '手段': 0.02097902097902098,
#  '段追': 0.07142857142857142,
#  '求富': 0.030303030303030304,
#  '富裕': 0.06666666666666667,
#  '裕物': 0.5,
#  '物质': 0.1111111111111111,
#  '质生': 0.06666666666666667,
#  '活的': 0.14545454545454545,
#  '了追': 0.000949667616334283,
#  '求黛': 0.030303030303030304,
#  '茜耗': 0.02857142857142857,
#  '耗尽': 1.0,
#  '尽了': 0.037037037037037035,
#  '了自': 0.003798670465337132,
#  '自己': 0.5617283950617284,
#  '己的': 0.37362637362637363,
#  '的感': 0.0040615027560197275,
#  '感情': 0.15447154471544716,
#  '情和': 0.007042253521126761,
#  '和才': 0.0033222591362126247,
#  '才智': 0.010309278350515464,
#  '最后': 0.42391304347826086,
#  '后葬': 0.0031645569620253164,
#  '葬送': 0.2,
#  '送掉': 0.029411764705882353,
#  '掉自': 0.01818181818181818,
#  '他天': 0.0006105006105006105,
#  '天真': 0.022026431718061675,
#  '真地': 0.05405405405405406,
#  '地以': 0.004335260115606936,
#  '为有': 0.009868421052631578,
#  '钱就': 0.058823529411764705,
#  '就能': 0.002369668246445498,
#  '能重': 0.0234375,
#  '重温': 0.07142857142857142,
#  '温旧': 0.25,
#  '旧梦': 0.2222222222222222,
#  '赎回': 1.0,
#  '回失': 0.005649717514124294,
#  '可惜': 0.013029315960912053,
#  '他错': 0.0006105006105006105,
#  '错了': 0.4090909090909091,
#  '他看': 0.009157509157509158,
#  '看错': 0.007853403141361256,
#  '了黛': 0.008547008547008548,
#  '茜这': 0.02857142857142857,
#  '这个': 0.18195956454121306,
#  '个粗': 0.0036231884057971015,
#  '粗俗': 0.04,
#  '俗浅': 0.16666666666666666,
#  '浅薄': 0.2,
#  '薄的': 0.2,
#  '女人': 0.3469387755102041,
#  '了表': 0.000949667616334283,
#  '表面': 0.011235955056179775,
#  '面上': 0.023809523809523808,
#  '上灯': 0.0016233766233766235,
#  '灯红': 0.046511627906976744,
#  '红酒': 0.07142857142857142,
#  '酒绿': 0.03333333333333333,
#  '绿而': 0.041666666666666664,
#  '而精': 0.00558659217877095,
#  '精神': 0.37037037037037035,
#  '神上': 0.0125,
#  '上空': 0.011363636363636364,
#  '空虚': 0.07692307692307693,
#  '虚无': 0.1111111111111111,
#  '无聊': 0.03759398496240601,
#  '聊的': 0.14285714285714285,
#  '的社': 0.0011604293588627793,
#  '他生': 0.0018315018315018315,
#  '活在': 0.03636363636363636,
#  '在梦': 0.0008503401360544217,
#  '梦幻': 0.14285714285714285,
#  '幻之': 0.047619047619047616,
#  '被黛': 0.023255813953488372,
#  '茜抛': 0.02857142857142857,
#  '抛弃': 0.3333333333333333,
#  '为社': 0.003289473684210526,
#  '会冷': 0.0041841004184100415,
#  '冷落': 0.03333333333333333,
#  '终于': 0.4090909090909091,
#  '于铸': 0.005154639175257732,
#  '铸成': 0.5,
#  '成了': 0.21212121212121213,
#  '了无': 0.000949667616334283,
#  '无法': 0.06766917293233082,
#  '法挽': 0.029850746268656716,
#  '回的': 0.005649717514124294,
#  '比是': 0.005698005698005698,
#  '是2': 0.000794912559618442,
#  '代典': 0.027777777777777776,
#  '典型': 0.6666666666666666,
#  '型的': 0.2857142857142857,
#  '国青': 0.03296703296703297,
#  '青年': 0.5789473684210527,
#  '的遭': 0.0005802146794313896,
#  '遭遇': 0.4,
#  '遇正': 0.16666666666666666,
#  '正是': 0.1171875,
#  '是欢': 0.000794912559618442,
#  '欢歌': 0.017543859649122806,
#  '歌笑': 0.07142857142857142,
#  '笑舞': 0.02040816326530612,
#  '舞的': 0.06896551724137931,
#  '的爵': 0.0005802146794313896,
#  '爵士': 0.8333333333333334,
#  '士时': 0.2857142857142857,
#  '时代': 0.04522613065326633,
#  '代的': 0.25,
#  '的写': 0.0002901073397156948,
#  '写照': 0.03333333333333333,
#  '者为': 0.018518518518518517,
#  '为小': 0.006578947368421052,
#  '说设': 0.0035714285714285713,
#  '设计': 0.16666666666666666,
#  '计了': 0.1,
#  '个双': 0.0012077294685990338,
#  '双重': 0.07692307692307693,
#  '重主': 0.014285714285714285,
#  '主人': 0.2127659574468085,
#  '人公': 0.0030721966205837174,
#  '公尼': 0.015384615384615385,
#  '克卡': 0.008,
#  '的重': 0.0005802146794313896,
#  '重要': 0.11428571428571428,
#  '要性': 0.0036363636363636364,
#  '性在': 0.05,
#  '在许': 0.0008503401360544217,
#  '许多': 0.40298507462686567,
#  '多方': 0.007518796992481203,
#  '方面': 0.13157894736842105,
#  '面不': 0.013605442176870748,
#  '不亚': 0.0009057971014492754,
#  '亚于': 0.07142857142857142,
#  '于主': 0.005154639175257732,
#  '公盖': 0.015384615384615385,
#  '他既': 0.0018315018315018315,
#  '既是': 0.047619047619047616,
#  '是故': 0.0023847376788553257,
#  '的叙': 0.0005802146794313896,
#  '叙述': 0.6666666666666666,
#  '述者': 0.25,
#  '者和': 0.05555555555555555,
#  '和评': 0.0033222591362126247,
#  '评论': 0.3333333333333333,
#  '论者': 0.07692307692307693,
#  '又是': 0.04198473282442748,
#  '是小': 0.0047694753577106515,
#  '说中': 0.007142857142857143,
#  '中一': 0.021645021645021644,
#  '个重': 0.0024154589371980675,
#  '要人': 0.0036363636363636364,
#  '人物': 0.019969278033794162,
#  '与矛': 0.034482758620689655,
#  '矛盾': 0.5,
#  '盾着': 1.0,
#  '的双': 0.0005802146794313896,
#  '双方': 0.07692307692307693,
#  '方都': 0.039473684210526314,
#  '都有': 0.03636363636363636,
#  '有千': 0.002680965147453083,
#  '千丝': 0.05555555555555555,
#  '丝万': 0.1,
#  '万缕': 0.038461538461538464,
#  '缕的': 0.25,
#  '的关': 0.0037713954163040323,
#  '关系': 0.28125,
#  '他是': 0.028693528693528692,
#  '居和': 0.04,
#  '和朋': 0.0033222591362126247,
#  '是黛': 0.007154213036565978,
#  '表哥': 0.011235955056179775,
#  '哥汤': 0.027777777777777776,
#  '还热': 0.004464285714285714,
#  '恋着': 0.14285714285714285,
#  '着黛': 0.012875536480686695,
#  '的好': 0.0026109660574412533,
#  '好友': 0.004975124378109453,
#  '友乔': 0.034482758620689655,
#  '乔丹': 0.8131868131868132,
#  '他充': 0.0006105006105006105,
#  '充当': 0.041666666666666664,
#  ...}

# %% [markdown]
# ### trigram
#
# 实现trigram算法，返回每个词的概率分布
#
# 输出示例：
# ```
# {'了不起': 0.5625,
#  '不起的': 0.5294117647058824,
#  '起的盖': 0.5333333333333333,
#  '的盖茨': 0.8666666666666667,
#  '盖茨比': 1.0,
#  '作者弗': 0.125,
#  '者弗司': 1.0,
#  '弗司各': 1.0,
#  '司各特': 0.8,
#  '各特菲': 0.75,
#  '特菲茨': 1.0,
#  '菲茨杰': 1.0,
#  '茨杰拉': 1.0,
#  '杰拉德': 1.0,
#  '美国中': 0.046511627906976744,
#  '国中西': 1.0,
#  '中西部': 1.0,
#  '西部城': 0.10526315789473684,
#  '部城市': 1.0,
#  '城市卡': 0.1,
#  '市卡罗': 1.0,
#  '卡罗威': 0.8666666666666667,
#  '罗威世': 0.1111111111111111,
#  '威世家': 1.0,
#  '世家的': 1.0,
# ...
#  '性在许': 1.0,
#  '在许多': 1.0,
#  '许多方': 0.038461538461538464,
#  '多方面': 1.0,
#  ...}
# ```

# %%
def calculate_trigram_probabilities(corpus):

    trigram_counts = defaultdict(int)
    bigram_counts = defaultdict(int)
    
    for sentence in corpus:
        chars = list(sentence)
        for i in range(len(chars) - 1):
            # 统计bigram
            bigram = chars[i] + chars[i + 1]
            bigram_counts[bigram] += 1
            
            # 统计trigram
            if i < len(chars) - 2:
                trigram = chars[i] + chars[i + 1] + chars[i + 2]
                trigram_counts[trigram] += 1
    
    # 计算概率
    trigram_probabilities = {}
    for trigram, count in trigram_counts.items():
        bigram = trigram[:2]
        if bigram_counts[bigram] > 0:
            probability = count / bigram_counts[bigram]
            trigram_probabilities[trigram] = probability
    
    return trigram_probabilities

calculate_trigram_probabilities(corpus)
# Out:
# {'了不起': 0.5625,
#  '不起的': 0.3103448275862069,
#  '起的盖': 0.47058823529411764,
#  '的盖茨': 0.8666666666666667,
#  '盖茨比': 1.0,
#  '作者弗': 0.125,
#  '者弗司': 1.0,
#  '弗司各': 1.0,
#  '司各特': 0.8,
#  '各特菲': 0.75,
#  '特菲茨': 1.0,
#  '菲茨杰': 1.0,
#  '茨杰拉': 1.0,
#  '杰拉德': 1.0,
#  '美国中': 0.046511627906976744,
#  '国中西': 1.0,
#  '中西部': 1.0,
#  '西部城': 0.1,
#  '部城市': 1.0,
#  '城市卡': 0.08333333333333333,
#  '市卡罗': 1.0,
#  '卡罗威': 0.8666666666666667,
#  '罗威世': 0.07692307692307693,
#  '威世家': 1.0,
#  '世家的': 0.5,
#  '家的后': 0.05263157894736842,
#  '的后裔': 0.3333333333333333,
#  '后裔尼': 0.5,
#  '裔尼克': 1.0,
#  '尼克厌': 0.023809523809523808,
#  '克厌倦': 1.0,
#  '厌倦了': 0.5,
#  '倦了中': 1.0,
#  '了中西': 0.3333333333333333,
#  '西部的': 0.2,
#  '部的生': 0.3333333333333333,
#  '的生活': 0.5625,
#  '到纽约': 1.0,
#  '纽约当': 0.02,
#  '约当证': 1.0,
#  '当证券': 1.0,
#  '证券交': 0.25,
#  '券交易': 1.0,
#  '交易人': 0.3333333333333333,
#  '易人并': 1.0,
#  '人并在': 0.25,
#  '并在市': 1.0,
#  '在市郊': 1.0,
#  '市郊长': 1.0,
#  '郊长岛': 1.0,
#  '长岛西': 0.13333333333333333,
#  '岛西卵': 1.0,
#  '西卵区': 0.038461538461538464,
#  '卵区租': 0.5,
#  '区租了': 1.0,
#  '租了一': 0.5,
#  '了一套': 0.0078125,
#  '一套小': 0.08333333333333333,
#  '套小屋': 1.0,
#  '他的邻': 0.004651162790697674,
#  '的邻居': 1.0,
#  '邻居便': 0.1,
#  '居便是': 1.0,
#  '便是豪': 1.0,
#  '是豪华': 1.0,
#  '豪华的': 0.45454545454545453,
#  '华的盖': 0.2,
#  '茨比公': 0.003067484662576687,
#  '比公馆': 1.0,
#  '小海湾': 1.0,
#  '海湾对': 0.21428571428571427,
#  '湾对面': 0.75,
#  '对面的': 0.14285714285714285,
#  '面的东': 0.038461538461538464,
#  '的东卵': 0.045454545454545456,
#  '东卵区': 0.1111111111111111,
#  '卵区宫': 0.5,
#  '区宫殿': 1.0,
#  '宫殿式': 0.6,
#  '殿式的': 1.0,
#  '式的大': 0.25,
#  '的大厦': 0.13333333333333333,
#  '大厦住': 0.2,
#  '厦住着': 1.0,
#  '住着从': 1.0,
#  '着从芝': 1.0,
#  '从芝加': 1.0,
#  '芝加哥': 1.0,
#  '加哥搬': 0.09090909090909091,
#  '哥搬来': 0.5,
#  '搬来的': 1.0,
#  '来的汤': 0.02247191011235955,
#  '的汤姆': 1.0,
#  '汤姆和': 0.07655502392344497,
#  '姆和黛': 0.375,
#  '和黛茜': 0.3,
#  '黛茜夫': 0.027777777777777776,
#  '茜夫妇': 1.0,
#  '黛茜是': 0.027777777777777776,
#  '茜是尼': 1.0,
#  '是尼克': 1.0,
#  '尼克的': 0.047619047619047616,
#  '克的远': 0.5,
#  '的远房': 0.3333333333333333,
#  '远房表': 1.0,
#  '房表妹': 1.0,
#  '汤姆是': 0.009569377990430622,
#  '姆是他': 0.5,
#  '是他大': 0.020833333333333332,
#  '他大学': 0.08333333333333333,
#  '大学里': 0.09523809523809523,
#  '学里的': 0.5,
#  '里的同': 0.024390243902439025,
#  '的同学': 0.375,
#  '家里很': 0.03571428571428571,
#  '里很有': 0.25,
#  '很有钱': 0.16666666666666666,
#  '他性情': 1.0,
#  '性情暴': 0.6666666666666666,
#  '情暴戾': 1.0,
#  '暴戾盛': 0.5,
#  '戾盛气': 1.0,
#  '盛气凌': 1.0,
#  '气凌人': 1.0,
#  '黛茜忧': 0.027777777777777776,
#  '茜忧郁': 1.0,
#  '忧郁而': 0.6666666666666666,
#  '郁而美': 1.0,
#  '而美丽': 1.0,
#  '她是盖': 0.058823529411764705,
#  '是盖茨': 0.9375,
#  '茨比以': 0.003067484662576687,
#  '比以前': 1.0,
#  '以前的': 0.0425531914893617,
#  '前的恋': 0.1,
#  '的恋人': 0.3333333333333333,
#  '杰伊盖': 0.9166666666666666,
#  '伊盖茨': 1.0,
#  '茨比原': 0.003067484662576687,
#  '比原先': 1.0,
#  '原先是': 0.3333333333333333,
#  '先是个': 0.3333333333333333,
#  '是个穷': 0.044444444444444446,
#  '个穷中': 0.5,
#  '穷中尉': 1.0,
#  '双亲相': 1.0,
#  '亲相继': 1.0,
#  '相继去': 1.0,
#  '继去世': 1.0,
#  '他年轻': 0.5,
#  '年轻时': 0.11764705882352941,
#  '轻时与': 0.25,
#  '时与黛': 1.0,
#  '与黛茜': 1.0,
#  '黛茜费': 0.027777777777777776,
#  '茜费伊': 1.0,
#  '费伊热': 0.5,
#  '伊热恋': 1.0,
#  '因家境': 1.0,
#  '家境清': 1.0,
#  '境清寒': 1.0,
#  '清寒又': 1.0,
#  '寒又默': 1.0,
#  '又默默': 1.0,
#  '默默无': 0.6666666666666666,
#  '默无闻': 1.0,
#  '不能跟': 0.05555555555555555,
#  '能跟她': 0.6666666666666666,
#  '跟她结': 0.1,
#  '她结婚': 0.6666666666666666,
#  '后来他': 0.13793103448275862,
#  '来他到': 0.07142857142857142,
#  '他到欧': 0.14285714285714285,
#  '到欧洲': 1.0,
#  '欧洲参': 0.2,
#  '洲参加': 1.0,
#  '参加第': 0.05263157894736842,
#  '加第一': 1.0,
#  '第一次': 0.46875,
#  '一次大': 0.02127659574468085,
#  '次大战': 0.5,
#  '黛茜就': 0.027777777777777776,
#  '茜就嫁': 1.0,
#  '就嫁给': 1.0,
#  '嫁给富': 0.125,
#  '给富家': 1.0,
#  '富家子': 1.0,
#  '家子弟': 1.0,
#  '子弟汤': 0.5,
#  '弟汤姆': 1.0,
#  '汤姆布': 0.09569377990430622,
#  '姆布坎': 1.0,
#  '布坎农': 1.0,
#  '但汤姆': 1.0,
#  '汤姆另': 0.004784688995215311,
#  '姆另有': 1.0,
#  '另有情': 1.0,
#  '有情妇': 1.0,
#  '黛茜并': 0.027777777777777776,
#  '茜并不': 1.0,
#  '并不愉': 0.020833333333333332,
#  '不愉快': 1.0,
#  '她把一': 0.25,
#  '把一切': 0.21428571428571427,
#  '一切都': 0.35,
#  '切都看': 0.06666666666666667,
#  '都看透': 0.16666666666666666,
#  '看透了': 1.0,
#  '茨比如': 0.003067484662576687,
#  '比如今': 0.5,
#  '如今又': 0.5,
#  '今又出': 1.0,
#  '又出现': 0.6666666666666666,
#  '出现在': 0.34615384615384615,
#  '现在她': 0.03260869565217391,
#  '在她的': 0.08,
#  '她的眼': 0.020618556701030927,
#  '的眼前': 0.06382978723404255,
#  '他还是': 0.3333333333333333,
#  '还是个': 0.04,
#  '是个单': 0.022222222222222223,
#  '个单身': 0.6,
#  '单身汉': 0.8,
#  '他买了': 0.5,
#  '买了一': 0.8333333333333334,
#  '了一座': 0.01171875,
#  '一座大': 0.1875,
#  '座大别': 0.25,
#  '大别墅': 1.0,
#  '黛茜的': 0.2222222222222222,
#  '茜的住': 0.125,
#  '的住处': 0.375,
#  '住处相': 0.25,
#  '处相对': 1.0,
#  '他靠非': 0.5,
#  '靠非法': 1.0,
#  '非法买': 0.25,
#  '法买卖': 1.0,
#  '买卖发': 0.25,
#  '卖发了': 1.0,
#  '发了横': 0.3333333333333333,
#  '了横财': 1.0,
#  '每晚举': 1.0,
#  '晚举行': 1.0,
#  '举行盛': 0.2857142857142857,
#  '行盛大': 1.0,
#  '盛大宴': 0.5,
#  '大宴会': 0.5,
#  '从纽约': 0.7777777777777778,
#  '纽约大': 0.02,
#  '约大量': 1.0,
#  '大量运': 0.5,
#  '量运来': 1.0,
#  '运来各': 0.5,
#  '来各种': 1.0,
#  '各种名': 0.07692307692307693,
#  '种名酒': 1.0,
#  '名酒和': 1.0,
#  '酒和食': 0.3333333333333333,
#  '和食品': 1.0,
#  '食品招': 0.14285714285714285,
#  '品招待': 1.0,
#  '招待各': 0.3333333333333333,
#  '待各界': 1.0,
#  '各界朋': 1.0,
#  '界朋友': 1.0,
#  '想以此': 1.0,
#  '以此引': 1.0,
#  '此引起': 1.0,
#  '引起黛': 0.09090909090909091,
#  '起黛茜': 1.0,
#  '茜的注': 0.125,
#  '的注目': 0.2,
#  '恢复他': 0.25,
#  '复他俩': 1.0,
#  '他俩失': 0.09090909090909091,
#  '俩失去': 1.0,
#  '失去的': 0.5714285714285714,
#  '去的爱': 0.08695652173913043,
#  '的爱情': 0.8571428571428571,
#  '尼克有': 0.023809523809523808,
#  '克有幸': 1.0,
#  '有幸光': 0.5,
#  '幸光顾': 1.0,
#  '光顾盖': 0.6666666666666666,
#  '顾盖茨': 1.0,
#  '茨比的': 0.18404907975460122,
#  '比的盛': 0.015384615384615385,
#  '的盛宴': 0.5,
#  '他想盖': 0.1,
#  '想盖茨': 1.0,
#  '茨比在': 0.018404907975460124,
#  '比在我': 0.3333333333333333,
#  '在我眼': 0.06349206349206349,
#  '我眼中': 0.42857142857142855,
#  '眼中有': 0.5,
#  '中有了': 0.125,
#  '有了生': 0.125,
#  '了生命': 0.6666666666666666,
#  '忽然之': 0.14285714285714285,
#  '然之间': 1.0,
#  '之间从': 0.08,
#  '间从他': 1.0,
#  '从他那': 0.15,
#  '他那子': 0.04878048780487805,
#  '那子宫': 1.0,
#  '子宫般': 1.0,
#  '宫般的': 1.0,
#  '般的毫': 0.16666666666666666,
#  '的毫无': 1.0,
#  '毫无目': 0.1111111111111111,
#  '无目的': 1.0,
#  '目的的': 0.2857142857142857,
#  '的的豪': 0.6666666666666666,
#  '的豪华': 1.0,
#  '豪华里': 0.18181818181818182,
#  '华里分': 1.0,
#  '里分娩': 0.6666666666666666,
#  '分娩出': 0.5,
#  '娩出来': 1.0,
#  '茨比请': 0.003067484662576687,
#  '比请尼': 1.0,
#  '请尼克': 1.0,
#  '尼克安': 0.023809523809523808,
#  '克安排': 1.0,
#  '安排他': 0.14285714285714285,
#  '排他与': 1.0,
#  '他与黛': 0.5,
#  '茜的会': 0.125,
#  '的会面': 0.3333333333333333,
#  '比在他': 0.16666666666666666,
#  '在他的': 0.12698412698412698,
#  '他的别': 0.009302325581395349,
#  '的别墅': 1.0,
#  '别墅与': 0.05,
#  '墅与黛': 1.0,
#  '黛茜第': 0.027777777777777776,
#  '茜第一': 1.0,
#  '一次见': 0.0851063829787234,
#  '次见了': 0.16666666666666666,
#  '见了面': 0.05263157894736842,
#  '又激动': 1.0,
#  '激动又': 0.05263157894736842,
#  '动又惶': 1.0,
#  '又惶惑': 1.0,
#  '她的表': 0.020618556701030927,
#  '的表情': 0.75,
#  '表情告': 0.043478260869565216,
#  '情告诉': 1.0,
#  '告诉他': 0.26153846153846155,
#  '诉他可': 0.058823529411764705,
#  '他可以': 0.75,
#  '可以挽': 0.012658227848101266,
#  '以挽回': 1.0,
#  '挽回昔': 0.3333333333333333,
#  '回昔日': 1.0,
#  '昔日的': 1.0,
#  '日的恋': 0.16666666666666666,
#  '的恋情': 0.3333333333333333,
#  '两人沉': 0.0625,
#  '人沉浸': 1.0,
#  '沉浸在': 1.0,
#  '浸在强': 0.6666666666666666,
#  '在强烈': 1.0,
#  '强烈的': 0.7142857142857143,
#  '烈的爱': 0.1111111111111111,
#  '爱情之': 0.1111111111111111,
#  '情之中': 1.0,
#  '把站在': 1.0,
#  '站在一': 0.12903225806451613,
#  '在一旁': 0.011363636363636364,
#  '一旁的': 0.5,
#  '旁的尼': 0.5,
#  '的尼克': 1.0,
#  '尼克都': 0.023809523809523808,
#  '克都遗': 1.0,
#  '都遗忘': 1.0,
#  '遗忘了': 0.6666666666666666,
#  '但尼克': 1.0,
#  '尼克觉': 0.023809523809523808,
#  '克觉得': 1.0,
#  '觉得黛': 0.0196078431372549,
#  '得黛茜': 0.5,
#  '黛茜远': 0.027777777777777776,
#  '茜远不': 1.0,
#  '远不如': 0.5714285714285714,
#  '不如盖': 0.16666666666666666,
#  '如盖茨': 1.0,
#  '比的梦': 0.015384615384615385,
#  '的梦想': 0.3076923076923077,
#  '他的幻': 0.018604651162790697,
#  '的幻梦': 0.5714285714285714,
#  '幻梦超': 0.3333333333333333,
#  '梦超越': 1.0,
#  '超越了': 1.0,
#  '越了她': 0.3333333333333333,
#  '越了一': 0.3333333333333333,
#  '了一切': 0.01171875,
#  '但黛茜': 0.5,
#  '黛茜激': 0.027777777777777776,
#  '茜激动': 1.0,
#  '激动的': 0.15789473684210525,
#  '动的声': 0.2,
#  '的声音': 0.9696969696969697,
#  '声音把': 0.024096385542168676,
#  '音把他': 0.5,
#  '把他迷': 0.02564102564102564,
#  '他迷住': 0.5,
#  '迷住了': 1.0,
#  '汤姆带': 0.009569377990430622,
#  '姆带黛': 0.5,
#  '带黛茜': 1.0,
#  '黛茜到': 0.027777777777777776,
#  '茜到盖': 1.0,
#  '到盖茨': 0.8421052631578947,
#  '茨比家': 0.03067484662576687,
#  '比家赴': 0.1,
#  '家赴宴': 1.0,
#  '茨比把': 0.006134969325153374,
#  '比把他': 0.5,
#  '把他的': 0.1794871794871795,
#  '他的来': 0.013953488372093023,
#  '的来宾': 0.1,
#  '来宾纽': 1.0,
#  '宾纽约': 1.0,
#  '纽约的': 0.1,
#  '约的女': 0.2,
#  '的女大': 0.045454545454545456,
#  '女大明': 0.5,
#  '大明星': 1.0,
#  '明星和': 0.2,
#  '星和名': 1.0,
#  '和名导': 1.0,
#  '名导演': 1.0,
#  '导演介': 0.3333333333333333,
#  '演介绍': 1.0,
#  '介绍给': 0.16666666666666666,
#  '绍给他': 0.5,
#  '给他俩': 0.0625,
#  '茨比与': 0.006134969325153374,
#  '比与黛': 1.0,
#  '黛茜跳': 0.027777777777777776,
#  '茜跳舞': 1.0,
#  '跳舞跳': 0.2,
#  '舞跳得': 1.0,
#  '跳得挺': 0.3333333333333333,
#  '得挺起': 0.5,
#  '挺起劲': 0.3333333333333333,
#  '但他感': 0.08333333333333333,
#  '他感到': 1.0,
#  '感到很': 0.1,
#  '到很难': 0.1,
#  '很难使': 0.4,
#  '难使她': 1.0,
#  '使她理': 0.25,
#  '她理解': 1.0,
#  '他想叫': 0.1,
#  '想叫黛': 0.5,
#  '叫黛茜': 1.0,
#  '黛茜对': 0.027777777777777776,
#  '茜对汤': 1.0,
#  '对汤姆': 1.0,
#  '汤姆说': 0.06220095693779904,
#  '她从来': 0.4,
#  '从来没': 0.7906976744186046,
#  '来没爱': 0.17647058823529413,
#  '没爱过': 1.0,
#  '爱过他': 0.4117647058823529,
#  '然后两': 0.010526315789473684,
#  '后两人': 0.5,
#  '两人自': 0.0625,
#  '人自由': 0.5,
#  '自由地': 0.25,
#  '由地回': 1.0,
#  '地回老': 0.1111111111111111,
#  '回老家': 1.0,
#  '老家去': 1.0,
#  '家去结': 0.1111111111111111,
#  '去结婚': 1.0,
#  '仿佛5': 0.012987012987012988,
#  '佛5年': 1.0,
#  '5年前': 0.5,
#  '年前那': 0.16666666666666666,
#  '前那样': 0.3333333333333333,
#  '黛茜果': 0.027777777777777776,
#  '茜果真': 1.0,
#  '果真总': 1.0,
#  '真总是': 1.0,
#  '总是在': 0.13636363636363635,
#  '是在下': 0.043478260869565216,
#  '在下午': 0.4,
#  '下午悄': 0.02040816326530612,
#  '午悄悄': 1.0,
#  '悄悄来': 0.1111111111111111,
#  '悄来盖': 1.0,
#  '来盖茨': 1.0,
#  '比家看': 0.1,
#  '家看他': 0.5,
#  '他把所': 0.05,
#  '把所有': 1.0,
#  '所有的': 0.5172413793103449,
#  '有的仆': 0.07692307692307693,
#  '的仆人': 1.0,
#  '仆人都': 0.2857142857142857,
#  '人都辞': 0.06896551724137931,
#  '都辞退': 0.5,
#  '辞退了': 1.0,
#  '尼克陪': 0.023809523809523808,
#  '克陪盖': 1.0,
#  '陪盖茨': 1.0,
#  '茨比去': 0.006134969325153374,
#  '比去黛': 0.5,
#  '去黛茜': 1.0,
#  '黛茜家': 0.027777777777777776,
#  '茜家作': 1.0,
#  '家作客': 1.0,
#  '汤姆很': 0.009569377990430622,
#  '姆很反': 0.5,
#  '很反感': 1.0,
#  '茨比发': 0.003067484662576687,
#  '比发觉': 1.0,
#  '发觉黛': 0.1,
#  '觉黛茜': 1.0,
#  '黛茜声': 0.027777777777777776,
#  '茜声音': 1.0,
#  '声音里': 0.04819277108433735,
#  '音里充': 0.25,
#  '里充满': 1.0,
#  '充满了': 0.8823529411764706,
#  '满了金': 0.09375,
#  '了金钱': 1.0,
#  '来他们': 0.14285714285714285,
#  '他们一': 0.04819277108433735,
#  '们一起': 0.46153846153846156,
#  '一起上': 0.022727272727272728,
#  '起上纽': 1.0,
#  '上纽约': 0.8333333333333334,
#  '纽约去': 0.18,
#  '汤姆责': 0.004784688995215311,
#  '姆责怪': 1.0,
#  '责怪盖': 0.5,
#  '怪盖茨': 1.0,
#  '茨比给': 0.003067484662576687,
#  '比给他': 1.0,
#  '给他制': 0.0625,
#  '他制造': 1.0,
#  '制造家': 0.25,
#  '造家庭': 1.0,
#  '家庭纠': 0.14285714285714285,
#  '庭纠纷': 1.0,
#  '大骂盖': 0.4,
#  '骂盖茨': 1.0,
#  '茨比私': 0.003067484662576687,
#  '比私自': 1.0,
#  '私自卖': 0.5,
#  '自卖酒': 1.0,
#  '卖酒精': 1.0,
#  '酒精赚': 0.5,
#  '精赚大': 1.0,
#  '赚大钱': 1.0,
#  '茨比忍': 0.003067484662576687,
#  '比忍着': 1.0,
#  '忍着跟': 1.0,
#  '着跟黛': 1.0,
#  '跟黛茜': 0.25,
#  '黛茜上': 0.027777777777777776,
#  '茜上一': 1.0,
#  '上一辆': 0.04,
#  '一辆车': 0.15789473684210525,
#  '尼克也': 0.023809523809523808,
#  '克也跟': 1.0,
#  '也跟他': 0.16666666666666666,
#  '跟他们': 0.11764705882352941,
#  '一起回': 0.022727272727272728,
#  '起回长': 1.0,
#  '回长岛': 1.0,
#  '黛茜因': 0.027777777777777776,
#  '茜因情': 1.0,
#  '因情绪': 1.0,
#  '情绪激': 0.25,
#  '绪激动': 1.0,
#  '开着盖': 0.16666666666666666,
#  '着盖茨': 1.0,
#  '比的车': 0.046153846153846156,
#  '的车子': 0.5135135135135135,
#  '车子在': 0.04411764705882353,
#  '子在归': 0.09090909090909091,
#  '在归途': 1.0,
#  '归途中': 1.0,
#  '途中将': 0.5,
#  '中将汤': 1.0,
#  '将汤姆': 1.0,
#  '汤姆的': 0.04784688995215311,
#  '姆的情': 0.17647058823529413,
#  '的情妇': 0.13636363636363635,
#  '情妇玛': 0.16666666666666666,
#  '妇玛特': 1.0,
#  '玛特尔': 1.0,
#  '特尔撞': 0.04,
#  '尔撞死': 1.0,
#  '撞死了': 0.6666666666666666,
#  '出事后': 0.3333333333333333,
#  '事后她': 0.4,
#  '后她匆': 0.14285714285714285,
#  '她匆忙': 1.0,
#  '匆忙驾': 0.25,
#  '忙驾车': 1.0,
#  '驾车逃': 1.0,
#  '车逃走': 1.0,
#  '特尔的': 0.04,
#  '尔的丈': 0.5,
#  '的丈夫': 1.0,
#  '丈夫威': 0.058823529411764705,
#  '夫威尔': 1.0,
#  '威尔逊': 0.9878048780487805,
#  '尔逊发': 0.012345679012345678,
#  '逊发现': 1.0,
#  '发现肇': 0.034482758620689655,
#  '现肇事': 1.0,
#  '肇事的': 1.0,
#  '事的汽': 0.125,
#  '的汽车': 0.8,
#  '汽车在': 0.07575757575757576,
#  '车在盖': 0.125,
#  '在盖茨': 1.0,
#  '以为是': 0.08,
#  '为是他': 0.14285714285714285,
#  '是他撞': 0.020833333333333332,
#  '他撞死': 1.0,
#  '死了妻': 0.05555555555555555,
#  '了妻子': 1.0,
#  '便悄悄': 1.0,
#  '悄悄地': 0.6666666666666666,
#  '悄地潜': 0.16666666666666666,
#  '地潜入': 1.0,
#  '潜入盖': 1.0,
#  '入盖茨': 1.0,
#  '比的别': 0.07692307692307693,
#  '把正在': 1.0,
#  '正在游': 0.025,
#  '在游泳': 1.0,
#  '游泳的': 0.2,
#  '泳的盖': 0.3333333333333333,
#  '茨比打': 0.012269938650306749,
#  '比打死': 0.25,
#  '打死了': 0.5,
#  '然后在': 0.021052631578947368,
#  '后在草': 0.5,
#  '在草丛': 0.25,
#  '草丛里': 1.0,
#  '丛里开': 0.5,
#  '里开枪': 0.5,
#  '开枪自': 0.5,
#  '枪自杀': 1.0,
#  '凶杀案': 1.0,
#  '杀案发': 1.0,
#  '案发生': 1.0,
#  '发生后': 0.037037037037037035,
#  '尼克打': 0.023809523809523808,
#  '克打电': 1.0,
#  '打电话': 1.0,
#  '电话给': 0.11764705882352941,
#  '话给黛': 0.3333333333333333,
#  '给黛茜': 0.16666666666666666,
#  '但她和': 0.16666666666666666,
#  '她和汤': 0.42857142857142855,
#  '和汤姆': 1.0,
#  '姆带了': 0.5,
#  '带了行': 0.5,
#  '了行李': 1.0,
#  '很早就': 1.0,
#  '早就出': 0.2857142857142857,
#  '就出门': 0.6666666666666666,
#  '出门去': 0.4,
#  '门去欧': 0.5,
#  '去欧洲': 1.0,
#  '欧洲旅': 0.2,
#  '洲旅行': 1.0,
#  '旅行了': 0.16666666666666666,
#  '黛茜既': 0.027777777777777776,
#  '茜既没': 1.0,
#  '既没打': 0.25,
#  '没打来': 0.2,
#  '打来电': 1.0,
#  '来电报': 0.6666666666666666,
#  '也没送': 0.0625,
#  '没送花': 1.0,
#  '送花圈': 0.5,
#  '往日一': 0.5,
#  '日一起': 1.0,
#  '一起花': 0.022727272727272728,
#  '起花天': 1.0,
#  '花天酒': 1.0,
#  '天酒地': 1.0,
#  '酒地的': 1.0,
#  '地的朋': 0.09090909090909091,
#  '的朋友': 1.0,
#  '朋友没': 0.02702702702702703,
#  '友没有': 1.0,
#  '没有一': 0.058823529411764705,
#  '有一个': 0.2653061224489796,
#  '一个来': 0.002770083102493075,
#  '个来参': 1.0,
#  '来参加': 1.0,
#  '参加盖': 0.10526315789473684,
#  '加盖茨': 1.0,
#  '比的葬': 0.015384615384615385,
#  '的葬礼': 1.0,
#  '唯有他': 0.25,
#  '有他年': 0.25,
#  '他年老': 0.5,
#  '年老的': 0.5,
#  '老的父': 0.25,
#  '的父亲': 0.5,
#  '父亲和': 0.1111111111111111,
#  '亲和尼': 1.0,
#  '和尼克': 1.0,
#  '茨比为': 0.006134969325153374,
#  '比为了': 1.0,
#  '为了久': 0.058823529411764705,
#  '了久久': 1.0,
#  '久久地': 1.0,
#  '久地抱': 1.0,
#  '地抱着': 1.0,
#  '抱着的': 0.2,
#  '着的一': 0.07692307692307693,
#  '的一个': 0.2777777777777778,
#  '一个梦': 0.00554016620498615,
#  '个梦而': 0.3333333333333333,
#  '梦而付': 1.0,
#  '而付出': 1.0,
#  '付出了': 0.6666666666666666,
#  '出了很': 0.0967741935483871,
#  '了很高': 0.18181818181818182,
#  '很高的': 0.15384615384615385,
#  '高的代': 0.2,
#  '的代价': 0.4,
#  '他死后': 0.3333333333333333,
#  '尼克发': 0.023809523809523808,
#  '克发觉': 1.0,
#  '发觉是': 0.1,
#  '觉是汤': 1.0,
#  '是汤姆': 1.0,
#  '汤姆暗': 0.004784688995215311,
#  '姆暗中': 1.0,
#  '暗中挑': 0.5,
#  '中挑拨': 0.5,
#  '挑拨威': 1.0,
#  '拨威尔': 1.0,
#  '尔逊去': 0.012345679012345678,
#  '逊去杀': 1.0,
#  '去杀死': 1.0,
#  '杀死盖': 0.6666666666666666,
#  '死盖茨': 1.0,
#  '感到东': 0.014285714285714285,
#  '到东部': 0.7777777777777778,
#  '东部鬼': 0.05263157894736842,
#  '部鬼影': 1.0,
#  '鬼影幢': 0.3333333333333333,
#  '影幢幢': 1.0,
#  '世态炎': 1.0,
#  '态炎凉': 1.0,
#  '便决定': 1.0,
#  '决定回': 0.25,
#  '定回中': 0.5,
#  '回中西': 1.0,
#  '西部老': 0.05,
#  '部老家': 1.0,
#  '作品赏': 0.14285714285714285,
#  '品赏析': 1.0,
#  '小说通': 0.05555555555555555,
#  '说通过': 1.0,
#  '通过完': 0.16666666666666666,
#  '过完美': 1.0,
#  '完美的': 1.0,
#  '美的艺': 0.25,
#  '的艺术': 1.0,
#  '艺术形': 0.25,
#  '术形式': 1.0,
#  '形式描': 0.2,
#  '式描写': 1.0,
#  '描写了': 1.0,
#  '写了2': 0.16666666666666666,
#  '了20': 1.0,
#  '20年': 1.0,
#  '0年代': 0.6666666666666666,
#  '年代贩': 0.25,
#  '代贩酒': 1.0,
#  '贩酒暴': 1.0,
#  '酒暴发': 1.0,
#  '暴发户': 1.0,
#  '发户盖': 0.5,
#  '户盖茨': 1.0,
#  '茨比所': 0.009202453987730062,
#  '比所追': 0.6666666666666666,
#  '所追求': 1.0,
#  '追求的': 0.18181818181818182,
#  '求的美': 0.5,
#  '的美国': 0.6,
#  '美国梦': 0.16279069767441862,
#  '国梦的': 0.5714285714285714,
#  '梦的幻': 0.2857142857142857,
#  '的幻灭': 0.14285714285714285,
#  '揭示了': 0.3333333333333333,
#  '示了美': 1.0,
#  '了美国': 1.0,
#  '美国社': 0.023255813953488372,
#  '国社会': 1.0,
#  '社会的': 0.5,
#  '会的悲': 0.09090909090909091,
#  '的悲剧': 0.4444444444444444,
#  '茜的恋': 0.125,
#  '的恋爱': 0.3333333333333333,
#  '恋爱和': 1.0,
#  '爱和分': 1.0,
#  '和分手': 1.0,
#  '分手本': 0.25,
#  '手本来': 1.0,
#  '本来是': 0.07142857142857142,
#  '来是个': 0.2222222222222222,
#  '是个很': 0.08888888888888889,
#  '个很普': 0.2,
#  '很普通': 1.0,
#  '普通的': 0.5,
#  '通的爱': 1.0,
#  '爱情故': 0.1111111111111111,
#  '情故事': 1.0,
#  '但作者': 1.0,
#  '作者出': 0.125,
#  '者出手': 0.5,
#  '出手不': 0.16666666666666666,
#  '手不凡': 1.0,
#  '把盖茨': 1.0,
#  '茨比热': 0.003067484662576687,
#  '比热恋': 1.0,
#  '热恋的': 0.25,
#  '恋的姑': 1.0,
#  '的姑娘': 0.8,
#  '姑娘当': 0.029411764705882353,
#  '娘当作': 1.0,
#  '当作青': 0.5,
#  '作青春': 1.0,
#  '青春金': 0.3333333333333333,
#  '春金钱': 1.0,
#  '金钱和': 0.125,
#  '钱和地': 1.0,
#  '和地位': 1.0,
#  '地位的': 0.5,
#  '位的象': 0.3333333333333333,
#  '的象征': 1.0,
#  '当作靠': 0.5,
#  '作靠手': 1.0,
#  '靠手段': 1.0,
#  '手段追': 0.3333333333333333,
#  '段追求': 1.0,
#  '追求富': 0.09090909090909091,
#  '求富裕': 1.0,
#  '富裕物': 1.0,
#  '裕物质': 1.0,
#  '物质生': 0.5,
#  '质生活': 1.0,
#  '生活的': 0.2,
#  '活的美': 0.125,
#  '为了追': 0.058823529411764705,
#  '了追求': 1.0,
#  '追求黛': 0.09090909090909091,
#  '求黛茜': 1.0,
#  '黛茜耗': 0.027777777777777776,
#  '茜耗尽': 1.0,
#  '耗尽了': 1.0,
#  '尽了自': 1.0,
#  '了自己': 0.75,
#  '自己的': 0.3516483516483517,
#  '己的感': 0.029411764705882353,
#  '的感情': 0.5714285714285714,
#  '感情和': 0.05263157894736842,
#  '情和才': 1.0,
#  '和才智': 1.0,
#  '最后葬': 0.02564102564102564,
#  '后葬送': 1.0,
#  '葬送掉': 1.0,
#  '送掉自': 1.0,
#  '掉自己': 1.0,
#  '己的生': 0.058823529411764705,
#  '的生命': 0.0625,
#  '他天真': 1.0,
#  '天真地': 0.8,
#  '真地以': 0.16666666666666666,
#  '地以为': 0.3333333333333333,
#  '以为有': 0.02,
#  '为有了': 0.3333333333333333,
#  '有了金': 0.0625,
#  '金钱就': 0.125,
#  '钱就能': 0.5,
#  '就能重': 1.0,
#  '能重温': 1.0,
#  '重温旧': 1.0,
#  '温旧梦': 1.0,
#  '赎回失': 1.0,
#  '回失去': 1.0,
#  '他错了': 1.0,
#  '他看错': 0.13333333333333333,
#  '看错了': 1.0,
#  '错了黛': 0.1111111111111111,
#  '了黛茜': 0.1111111111111111,
#  '黛茜这': 0.027777777777777776,
#  '茜这个': 1.0,
#  '这个粗': 0.008547008547008548,
#  '个粗俗': 0.3333333333333333,
#  '粗俗浅': 1.0,
#  '俗浅薄': 1.0,
#  '浅薄的': 1.0,
#  '薄的女': 0.3333333333333333,
#  '的女人': 0.36363636363636365,
#  '错了表': 0.1111111111111111,
#  '了表面': 1.0,
#  '表面上': 1.0,
#  '面上灯': 0.14285714285714285,
#  '上灯红': 1.0,
#  '灯红酒': 1.0,
#  '红酒绿': 1.0,
#  '酒绿而': 0.5,
#  '绿而精': 1.0,
#  '而精神': 1.0,
#  '精神上': 0.1,
#  '神上空': 1.0,
#  '上空虚': 0.14285714285714285,
#  '空虚无': 0.25,
#  '虚无聊': 1.0,
#  '无聊的': 0.2,
#  '聊的社': 1.0,
#  '的社会': 0.75,
#  '他生活': 0.6666666666666666,
#  '生活在': 0.08,
#  '活在梦': 0.5,
#  '在梦幻': 1.0,
#  '梦幻之': 0.16666666666666666,
#  '幻之中': 1.0,
#  '被黛茜': 1.0,
#  '黛茜抛': 0.027777777777777776,
#  '茜抛弃': 1.0,
#  '为社会': 1.0,
#  '社会冷': 0.125,
#  '会冷落': 1.0,
#  '终于铸': 0.1111111111111111,
#  '于铸成': 1.0,
#  '铸成了': 1.0,
#  '成了无': 0.07142857142857142,
#  '了无法': 1.0,
#  '无法挽': 0.1111111111111111,
#  '法挽回': 1.0,
#  '挽回的': 0.3333333333333333,
#  '回的悲': 1.0,
#  '茨比是': 0.006134969325153374,
#  '比是2': 0.5,
#  '是20': 1.0,
#  '年代典': 0.25,
#  '代典型': 1.0,
#  '典型的': 1.0,
#  '型的美': 0.25,
#  '美国青': 0.023255813953488372,
#  '国青年': 1.0,
#  '他的遭': 0.004651162790697674,
#  '的遭遇': 1.0,
#  '遭遇正': 0.5,
#  '遇正是': 1.0,
#  '正是欢': 0.06666666666666667,
#  '是欢歌': 1.0,
#  '欢歌笑': 1.0,
#  '歌笑舞': 1.0,
#  '笑舞的': 1.0,
#  '舞的爵': 0.5,
#  '的爵士': 0.5,
#  '爵士时': 0.6,
#  '士时代': 1.0,
#  '时代的': 0.5,
#  '代的写': 0.1111111111111111,
#  '的写照': 1.0,
#  '作者为': 0.125,
#  '者为小': 1.0,
#  '为小说': 0.5,
#  '小说设': 0.05555555555555555,
#  '说设计': 1.0,
#  '设计了': 1.0,
#  '计了一': 1.0,
#  '了一个': 0.09375,
#  '一个双': 0.002770083102493075,
#  '个双重': 1.0,
#  '双重主': 0.5,
#  '重主人': 1.0,
#  '主人公': 0.2,
#  '人公尼': 0.5,
#  '公尼克': 1.0,
#  '尼克卡': 0.023809523809523808,
#  '克卡罗': 1.0,
#  '他的重': 0.004651162790697674,
#  '的重要': 0.5,
#  '重要性': 0.125,
#  '要性在': 1.0,
#  '性在许': 1.0,
#  ...}

# %% [markdown]
# ### 计算句子概率
#
# 1. 使用上述计算得出的unigram, bigram, trigram结果，计算给定句子在unigram、bigram和trigram模型下的对数似然值。
#
# 输出格式:
# ```
# Unigram Negative Log-Likelihood: -16.467815940872697
# Bigram Negative Log-Likelihood: -0.10694757282788604
# Trigram Negative Log-Likelihood: 0.0
# ```
#
# 2. 处理包含多个句子的txt文件，计算每个句子的unigram, bigram, 和trigram负对数似然值，并将结果写入到result.txt

# %%
import math
def calculate_sentence_neg_log_likelihood(sentence, unigram_probabilities, bigram_probabilities, trigram_probabilities):
    """
    计算句子在unigram、bigram和trigram模型下的负对数似然值
    
    Args:
        sentence: 输入句子
        unigram_probabilities: unigram概率字典
        bigram_probabilities: bigram概率字典  
        trigram_probabilities: trigram概率字典
    
    Returns:
        tuple: (unigram_nll, bigram_nll, trigram_nll)
    """
    # 处理空句子
    if not sentence:
        return 0.0, 0.0, 0.0
    
    # 获取词汇表大小用于平滑
    vocab_size = len(unigram_probabilities)
    smoothing_factor = 1e-10  # 小的平滑因子，避免log(0)
    
    # Unigram负对数似然
    unigram_log_prob = 0.0
    for char in sentence:
        # 使用平滑处理未出现的字符
        prob = unigram_probabilities.get(char, smoothing_factor)
        unigram_log_prob += math.log(prob)
    unigram_nll = -unigram_log_prob
    
    # Bigram负对数似然
    bigram_log_prob = 0.0
    if len(sentence) >= 2:
        # 第一个字符的概率
        first_char_prob = unigram_probabilities.get(sentence[0], smoothing_factor)
        bigram_log_prob += math.log(first_char_prob)
        
        # 后续字符的条件概率
        for i in range(1, len(sentence)):
            bigram = sentence[i-1] + sentence[i]
            prob = bigram_probabilities.get(bigram, smoothing_factor)
            bigram_log_prob += math.log(prob)
    else:
        # 单字符句子
        prob = unigram_probabilities.get(sentence[0], smoothing_factor)
        bigram_log_prob = math.log(prob)
    
    bigram_nll = -bigram_log_prob
    
    # Trigram负对数似然
    trigram_log_prob = 0.0
    if len(sentence) >= 3:
        # 第一个字符的概率
        first_char_prob = unigram_probabilities.get(sentence[0], smoothing_factor)
        trigram_log_prob += math.log(first_char_prob)
        
        # 第二个字符的条件概率
        if len(sentence) >= 2:
            bigram = sentence[0] + sentence[1]
            second_char_prob = bigram_probabilities.get(bigram, smoothing_factor)
            trigram_log_prob += math.log(second_char_prob)
        
        # 后续字符的三元条件概率
        for i in range(2, len(sentence)):
            trigram = sentence[i-2] + sentence[i-1] + sentence[i]
            prob = trigram_probabilities.get(trigram, smoothing_factor)
            trigram_log_prob += math.log(prob)
    else:
        # 处理短句子
        if len(sentence) == 1:
            prob = unigram_probabilities.get(sentence[0], smoothing_factor)
            trigram_log_prob = math.log(prob)
        elif len(sentence) == 2:
            first_char_prob = unigram_probabilities.get(sentence[0], smoothing_factor)
            trigram_log_prob += math.log(first_char_prob)
            bigram = sentence[0] + sentence[1]
            second_char_prob = bigram_probabilities.get(bigram, smoothing_factor)
            trigram_log_prob += math.log(second_char_prob)
    
    trigram_nll = -trigram_log_prob
    
    return unigram_nll, bigram_nll, trigram_nll


# 示例句子
sentence = "盖茨比"

# 计算句子的对数似然值
unigram_nll, bigram_nll, trigram_nll = calculate_sentence_neg_log_likelihood(sentence, unigram_probabilities, bigram_probabilities, trigram_probabilities)

print(f"Unigram Negative Log-Likelihood: {unigram_nll}")
print(f"Bigram Negative Log-Likelihood: {bigram_nll}")
print(f"Trigram Negative Log-Likelihood: {trigram_nll}")

def process_sentences_file(filepath, unigram_probabilities, bigram_probabilities, trigram_probabilities, output_filepath):
    """
    处理包含多个句子的txt文件，计算每个句子的负对数似然值
    
    Args:
        filepath: 输入文件路径
        unigram_probabilities: unigram概率字典
        bigram_probabilities: bigram概率字典
        trigram_probabilities: trigram概率字典
        output_filepath: 输出文件路径
    """
    try:
        # 读取输入文件
        with open(filepath, 'r', encoding='utf-8') as f:
            sentences = [line.strip() for line in f if line.strip()]
        
        # 计算每个句子的负对数似然值
        results = []
        for i, sentence in enumerate(sentences, 1):
            unigram_nll, bigram_nll, trigram_nll = calculate_sentence_neg_log_likelihood(
                sentence, unigram_probabilities, bigram_probabilities, trigram_probabilities
            )
            
            result_line = f"句子 {i}: '{sentence}'\n"
            result_line += f"Unigram Negative Log-Likelihood: {unigram_nll}\n"
            result_line += f"Bigram Negative Log-Likelihood: {bigram_nll}\n"
            result_line += f"Trigram Negative Log-Likelihood: {trigram_nll}\n"
            result_line += "-" * 50 + "\n"
            
            results.append(result_line)
            print(result_line)
        
        # 写入输出文件
        with open(output_filepath, 'w', encoding='utf-8') as f:
            f.write("句子概率计算结果\n")
            f.write("=" * 50 + "\n\n")
            f.writelines(results)
        
        print(f"结果已保存到: {output_filepath}")
        
    except FileNotFoundError:
        print(f"错误: 找不到文件 {filepath}")
    except Exception as e:
        print(f"处理文件时出错: {e}")

# %% [markdown]
# 计算平滑后的概率

# %%
#计算平滑后的概率
def _calculate_ngram_probabilities(corpus, n, alpha=1.0):
    """
    通用的N-gram概率计算函数，支持加法平滑。

    Args:
        corpus (list of str): 文本语料库。
        n (int): N-gram的阶数 (1 for unigram, 2 for bigram, 3 for trigram)。
        alpha (float): 平滑参数。默认为1.0 (拉普拉斯平滑)。

    Returns:
        dict: N-gram的概率分布字典。
    """
    if not corpus:
        return {}

    # 1. 构建词汇表
    vocab = set()
    for sentence in corpus:
        for char in sentence:
            vocab.add(char)
    V = len(vocab) # 词汇表大小

    # 2. 统计N-gram和(N-1)-gram的计数
    ngram_counts = defaultdict(int)
    context_counts = defaultdict(int)
    
    total_words = 0 # 用于unigram计算

    for sentence in corpus:
        chars = list(sentence)
        total_words += len(chars)
        
        # 统计(N-1)-gram (上下文)的计数
        for i in range(len(chars) - n + 2):
            context = tuple(chars[i : i + n - 1])
            if context: # 确保上下文不为空
                context_counts[context] += 1
        
        # 统计N-gram的计数
        for i in range(len(chars) - n + 1):
            ngram = tuple(chars[i : i + n])
            ngram_counts[ngram] += 1
            
    # 3. 计算平滑后的概率
    probabilities = {}
    for ngram, count in ngram_counts.items():
        context = ngram[:-1]
        
        # 获取上下文计数
        if n == 1: # Unigram的上下文是总词数
            context_count = total_words
        else:
            context_count = context_counts.get(context, 0)
            
        # 应用加法平滑公式
        probability = (count + alpha) / (context_count + alpha * V)
        
        # 将元组转换为字符串作为键，方便使用
        probabilities[''.join(ngram)] = probability
        
    return probabilities

# %% [markdown]
# 计算perplexity

# %%
#计算perplexity
import numpy as np
def perplexity(model, test_data, vocab_size):
    total_log_prob = 0
    total_words = 0
    for sentence in test_data:
        log_prob = model.log_prob(sentence)
        total_log_prob += log_prob
        total_words += len(sentence)
    perplexity = np.exp(-total_log_prob / total_words)
    return perplexity
